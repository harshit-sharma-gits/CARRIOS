# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Untitled.ipynb']

# %%
dataset = pd.read_excel("RADHE.xlsx")

# %%
dataset
# Out:
#          Unnamed: 0       Make      Model    Variant        Ex-Showroom_Price  \
# 0          0.000000       Tata  Nano Genx         Xt             Rs. 2,92,667
# 1          1.000000       Tata  Nano Genx         Xe             Rs. 2,36,447
# 2          2.000000       Tata  Nano Genx    Emax Xm             Rs. 2,96,661
# 3          3.000000       Tata  Nano Genx        Xta             Rs. 3,34,768
# 4          4.000000       Tata  Nano Genx         Xm             Rs. 2,72,223
# ...             ...        ...        ...        ...                      ...
# 1048570   32.032920   34.75434          1      [144]  2020-02-04 03:09:03 UTC
# 1048571   32.119140   34.83897          2  [79, 268]  2020-02-04 03:09:03 UTC
# 1048572   32.123610   34.80693          1      [145]  2020-02-04 03:09:03 UTC
# 1048573   32.075000   34.80216          1       [27]  2020-02-04 03:09:03 UTC
# 1048574   32.116782  34.843358          1      [118]  2020-02-04 03:09:03 UTC
#
# ...

# %%
dataset.set_index(dataset["Make"],inplace=True)

# %%
dataset
# Out:
#            Unnamed: 0       Make      Model    Variant  \
# Make
# Tata         0.000000       Tata  Nano Genx         Xt
# Tata         1.000000       Tata  Nano Genx         Xe
# Tata         2.000000       Tata  Nano Genx    Emax Xm
# Tata         3.000000       Tata  Nano Genx        Xta
# Tata         4.000000       Tata  Nano Genx         Xm
# ...               ...        ...        ...        ...
# 34.75434    32.032920   34.75434          1      [144]
# 34.83897    32.119140   34.83897          2  [79, 268]
# 34.80693    32.123610   34.80693          1      [145]
# 34.80216    32.075000   34.80216          1       [27]
# 34.843358   32.116782  34.843358          1      [118]
#
#                  Ex-Showroom_Price Displacement Fuel_Tank_Capacity Fuel_Type  \
# Make
# Tata                  Rs. 2,92,667       624 cc          24 litres    Petrol
# Tata                  Rs. 2,36,447       624 cc          24 litres    Petrol
# ...

# %%
dataset.drop("Unnamed: 0",inplace=True,axis=1)

# %%
dataset
# Out:
#                 Make      Model    Variant        Ex-Showroom_Price  \
# Make
# Tata            Tata  Nano Genx         Xt             Rs. 2,92,667
# Tata            Tata  Nano Genx         Xe             Rs. 2,36,447
# Tata            Tata  Nano Genx    Emax Xm             Rs. 2,96,661
# Tata            Tata  Nano Genx        Xta             Rs. 3,34,768
# Tata            Tata  Nano Genx         Xm             Rs. 2,72,223
# ...              ...        ...        ...                      ...
# 34.75434    34.75434          1      [144]  2020-02-04 03:09:03 UTC
# 34.83897    34.83897          2  [79, 268]  2020-02-04 03:09:03 UTC
# 34.80693    34.80693          1      [145]  2020-02-04 03:09:03 UTC
# 34.80216    34.80216          1       [27]  2020-02-04 03:09:03 UTC
# 34.843358  34.843358          1      [118]  2020-02-04 03:09:03 UTC
#
#           Displacement Fuel_Tank_Capacity Fuel_Type    City_Mileage  \
# Make
# ...

# %%
dataset.notna().sum()
# Out:
# Make                              234113
# Model                             234188
# Variant                           234188
# Ex-Showroom_Price                 234188
# Displacement                        1264
# Fuel_Tank_Capacity                  1207
# Fuel_Type                           1276
# City_Mileage                         721
# Highway_Mileage                      476
# ARAI_Certified_Mileage              1162
# ARAI_Certified_Mileage_for_CNG        27
# Power                               1276
# Torque                              1274
# Odometer                            1233
# Speedometer                         1231
# Seating_Capacity                    1270
# Average_Fuel_Consumption             931
# Basic_Warranty                       836
# Boot_Space                          1027
# Extended_Warranty                    615
# Price_range                            0
# dtype: int64

# %%
dataset.dropna(subset=["Model"],inplace=True)

# %%
dataset.notna().sum()
# Out:
# Make                              234113
# Model                             234188
# Variant                           234188
# Ex-Showroom_Price                 234188
# Displacement                        1264
# Fuel_Tank_Capacity                  1207
# Fuel_Type                           1276
# City_Mileage                         721
# Highway_Mileage                      476
# ARAI_Certified_Mileage              1162
# ARAI_Certified_Mileage_for_CNG        27
# Power                               1276
# Torque                              1274
# Odometer                            1233
# Speedometer                         1231
# Seating_Capacity                    1270
# Average_Fuel_Consumption             931
# Basic_Warranty                       836
# Boot_Space                          1027
# Extended_Warranty                    615
# Price_range                            0
# dtype: int64
